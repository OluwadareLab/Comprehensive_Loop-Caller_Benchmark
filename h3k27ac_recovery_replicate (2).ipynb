# %%
import matplotlib.pyplot as plt

# %%
tools = ['LASCA','HiCExplorer', 'FitHiC', 'FitHiChIP','Peakachu','MUSTACHE','Chromosight','SIP','cLoops','cLoops2','HiCCUPS']

# %% [markdown]
# # h3k27ac recovery from replicate data for chromosome 1 @ 5KB

# %%
chromosight = [1000, 1184]
chromosight_frac = [0.231791600212653, 0.237816764132554]
cloops = [1000, 1658]
cloops_frac = [0.103313840155945, 0.156299840510367]
cloops2 = [1000, 2000, 2492]
cloops2_frac = [0.0203792309055467, 0.0267588162325004, 0.0317207159312422]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 33788]
fithic_frac = [0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934]
fithichip = [225]
fithichip_frac = [0.0806308701045543]
hiccups = [1000, 1943]
hiccups_frac = [0.219918483076378, 0.320042530568846]
hicexplorer = [1000, 1923]
hicexplorer_frac = [0.063973063973064, 0.134680134680135]
lasca = [1000, 2000, 3000, 3249]
lasca_frac = [0.0237462342725501, 0.0579479000531632, 0.0979975190501506, 0.109516214779373]
mustache = [1000, 2000, 2236]
mustache_frac = [0.143895091263512, 0.281233386496544, 0.307460570618465]
peakachu = [905]
peakachu_frac = [0.146907673223463]
sip = [608]
sip_frac = [0.157363104731526]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, cloops_frac, cloops2_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('H3K27ac')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('h3k27ac_box_recovery_replicate_chr1_5k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(cloops, cloops_frac, label = "cLoops",  marker='*', c='#ffa500')
plt.plot(cloops2, cloops2_frac, label = "cLoops2", marker='*', c='#ffff00')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("H3K27ac")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('h3k27ac_recovery_replicate_chr1_5k.png')
plt.show()

# %% [markdown]
# # h3k27ac recovery from replicate data for chromosome 1 @ 10KB

# %%
chromosight = [928]
chromosight_frac = [0.251160734026089]
cloops = [1000, 1658]
cloops_frac = [0.135750608003537, 0.188812734910458]
cloops2 = [1000, 2000, 2492]
cloops2_frac = [0.0325005527304886, 0.0444395312845457, 0.0581472474021667]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 25319]
fithic_frac = [0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686]
fithichip = [1000, 1864]
fithichip_frac = [0.221976564227283, 0.286314393101924]
hiccups = [1000, 2000, 2928]
hiccups_frac = [0.290957329206279, 0.409683838160513, 0.479770064116737]
hicexplorer = [1000, 1732]
hicexplorer_frac = [0.127570196772054, 0.202741543223524]
lasca = [1000, 1543]
lasca_frac = [0.0696440415653327, 0.133097501658191]
mustache = [1000, 2000, 3000, 4000, 4804]
mustache_frac = [0.0636745522883042, 0.172230820252045, 0.254919301348662, 0.330090647800133, 0.365686491266858]
peakachu = [1000, 2000, 2638]
peakachu_frac = [0.225956223745302, 0.33119610877736, 0.360601370771612]
sip = [361]
sip_frac = [0.138845898739774]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, cloops_frac, cloops2_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('H3K27ac')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('h3k27ac_box_recovery_replicate_chr1_10k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(cloops, cloops_frac, label = "cLoops",  marker='*', c='#ffa500')
plt.plot(cloops2, cloops2_frac, label = "cLoops2", marker='*', c='#ffff00')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("H3K27ac")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('h3k27ac_recovery_replicate_chr1_10k.png')
plt.show()

# %% [markdown]
# # h3k27ac recovery from replicate data for chromosome 6 @ 5KB

# %%
chromosight = [1000, 1184]
chromosight_frac = [0.231791600212653, 0.237816764132554]
cloops = [1000, 1658]
cloops_frac = [0.103313840155945, 0.156299840510367]
cloops2 = [1000, 2000, 2492]
cloops2_frac = [0.0203792309055467, 0.0267588162325004, 0.0317207159312422]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 33788]
fithic_frac = [0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934, 0.00407584618110934]
fithichip = [225]
fithichip_frac = [0.0806308701045543]
hiccups = [1000, 1943]
hiccups_frac = [0.219918483076378, 0.320042530568846]
hicexplorer = [1000, 1923]
hicexplorer_frac = [0.063973063973064, 0.134680134680135]
lasca = [1000, 2000, 3000, 3249]
lasca_frac = [0.0237462342725501, 0.0579479000531632, 0.0979975190501506, 0.109516214779373]
mustache = [1000, 2000, 2236]
mustache_frac = [0.143895091263512, 0.281233386496544, 0.307460570618465]
peakachu = [905]
peakachu_frac = [0.146907673223463]
sip = [608]
sip_frac = [0.157363104731526]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, cloops_frac, cloops2_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('H3K27ac')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('h3k27ac_box_recovery_replicate_chr6_5k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(cloops, cloops_frac, label = "cLoops",  marker='*', c='#ffa500')
plt.plot(cloops2, cloops2_frac, label = "cLoops2", marker='*', c='#ffff00')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("H3K27ac")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('h3k27ac_recovery_replicate_chr6_5k.png')
plt.show()

# %% [markdown]
# # h3k27ac recovery from replicate data for chromosome 6 @ 10KB

# %%
chromosight = [928]
chromosight_frac = [0.251160734026089]
cloops = [1000, 1658]
cloops_frac = [0.135750608003537, 0.188812734910458]
cloops2 = [1000, 2000, 2492]
cloops2_frac = [0.0325005527304886, 0.0444395312845457, 0.0581472474021667]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 25319]
fithic_frac = [0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686, 0.0236568649126686]
fithichip = [1000, 1864]
fithichip_frac = [0.221976564227283, 0.286314393101924]
hiccups = [1000, 2000, 2928]
hiccups_frac = [0.290957329206279, 0.409683838160513, 0.479770064116737]
hicexplorer = [1000, 1732]
hicexplorer_frac = [0.127570196772054, 0.202741543223524]
lasca = [1000, 1543]
lasca_frac = [0.0696440415653327, 0.133097501658191]
mustache = [1000, 2000, 3000, 4000, 4804]
mustache_frac = [0.0636745522883042, 0.172230820252045, 0.254919301348662, 0.330090647800133, 0.365686491266858]
peakachu = [1000, 2000, 2638]
peakachu_frac = [0.225956223745302, 0.33119610877736, 0.360601370771612]
sip = [361]
sip_frac = [0.138845898739774]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, cloops_frac, cloops2_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('H3K27ac')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('h3k27ac_box_recovery_replicate_chr6_10k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(cloops, cloops_frac, label = "cLoops",  marker='*', c='#ffa500')
plt.plot(cloops2, cloops2_frac, label = "cLoops2", marker='*', c='#ffff00')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("H3K27ac")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('h3k27ac_recovery_replicate_chr6_10k.png')
plt.show()
