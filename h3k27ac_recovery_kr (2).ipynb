# %%
import matplotlib.pyplot as plt

# %%
tools = ['LASCA','HiCExplorer', 'FitHiC', 'FitHiChIP','Peakachu','MUSTACHE','Chromosight','SIP','HiCCUPS']

# %% [markdown]
# # h3k27ac recovery from RAW data for chromosome 1 @ 5KB

# %%
chromosight = [1000, 1414]
chromosight_frac = [0.231791600212653, 0.24862661704767]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 33220]
fithic_frac = [0.00124047492468545, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479]
fithichip = [769]
fithichip_frac = [0]
hiccups = [1000, 2000, 3000, 3300]
hiccups_frac = [0.225234804182173, 0.314548998759525, 0.374623427255006, 0.392876129718235]
hicexplorer = [1000, 1757]
hicexplorer_frac = [0.0790359737728159, 0.135034556087188]
lasca = [1000, 2000, 3000, 3146]
lasca_frac = [0.0230373914584441, 0.050327839801524, 0.0987063618642566, 0.102959418748892]
mustache = [1000, 2000, 2808]
mustache_frac = [0.126174020910863, 0.256423888002835, 0.329611908559277]
peakachu = [1000, 2000, 3000, 3867]
peakachu_frac = [0.142654616338827, 0.238348396243133, 0.295233032075137, 0.311713627503101]
sip = [747]
sip_frac = [0.179514442672337]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('H3K27ac')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('h3k27ac_box_recovery_kr_chr1_5k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("H3K27ac")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('h3k27ac_recovery_kr_chr1_5k.png')
plt.show()

# %% [markdown]
# # h3k27ac recovery from RAW data for chromosome 1 @ 10KB

# %%
chromosight = [958]
chromosight_frac = [0.253150563785098]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 31575]
fithic_frac = [0.0599159849657307, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983]
fithichip = [1000, 2000, 3000, 3678]
fithichip_frac = [0, 0, 0, 0]
hiccups = [1000, 2000, 3000, 3888]
hiccups_frac = [0.289851868229052, 0.402608887906257, 0.473137298253372, 0.518682290515145]
hicexplorer = [1000, 1471]
hicexplorer_frac = [0.162502763652443, 0.215785982754809]
lasca = [1000, 1503]
lasca_frac = [0.0729604244970153, 0.133760778244528]
mustache = [1000, 2000, 3000, 4000, 5000, 5843]
mustache_frac = [0.0508512049524652, 0.140614636303338, 0.228830422286093, 0.297147910678753, 0.345788193676763, 0.379394207384479]
peakachu = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 7607]
peakachu_frac = [0.131107671899182, 0.235242095954013, 0.315277470705284, 0.384037143488835, 0.443289851868229, 0.476232588989609, 0.505858943179306, 0.525757240769401]
sip = [315]
sip_frac = [0.111651558699978]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('H3K27ac')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('h3k27ac_box_recovery_kr_chr1_10k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("H3K27ac")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('h3k27ac_recovery_kr_chr1_10k.png')
plt.show()

# %% [markdown]
# # h3k27ac recovery from RAW data for chromosome 6 @ 5KB

# %%
chromosight = [1000, 1414]
chromosight_frac = [0.231791600212653, 0.24862661704767]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 33220]
fithic_frac = [0.00124047492468545, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479, 0.00531632110579479]
fithichip = [769]
fithichip_frac = [0]
hiccups = [1000, 2000, 3000, 3300]
hiccups_frac = [0.225234804182173, 0.314548998759525, 0.374623427255006, 0.392876129718235]
hicexplorer = [1000, 1757]
hicexplorer_frac = [0.0790359737728159, 0.135034556087188]
lasca = [1000, 2000, 3000, 3146]
lasca_frac = [0.0230373914584441, 0.050327839801524, 0.0987063618642566, 0.102959418748892]
mustache = [1000, 2000, 2808]
mustache_frac = [0.126174020910863, 0.256423888002835, 0.329611908559277]
peakachu = [1000, 2000, 3000, 3867]
peakachu_frac = [0.142654616338827, 0.238348396243133, 0.295233032075137, 0.311713627503101]
sip = [747]
sip_frac = [0.179514442672337]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('H3K27ac')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('h3k27ac_box_recovery_kr_chr6_5k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("H3K27ac")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('h3k27ac_recovery_kr_chr6_5k.png')
plt.show()

# %% [markdown]
# # h3k27ac recovery from RAW data for chromosome 6 @ 10KB

# %%
chromosight = [958]
chromosight_frac = [0.253150563785098]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 31575]
fithic_frac = [0.0599159849657307, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983, 0.0787088215785983]
fithichip = [1000, 2000, 3000, 3678]
fithichip_frac = [0, 0, 0, 0]
hiccups = [1000, 2000, 3000, 3888]
hiccups_frac = [0.289851868229052, 0.402608887906257, 0.473137298253372, 0.518682290515145]
hicexplorer = [1000, 1471]
hicexplorer_frac = [0.162502763652443, 0.215785982754809]
lasca = [1000, 1503]
lasca_frac = [0.0729604244970153, 0.133760778244528]
mustache = [1000, 2000, 3000, 4000, 5000, 5843]
mustache_frac = [0.0508512049524652, 0.140614636303338, 0.228830422286093, 0.297147910678753, 0.345788193676763, 0.379394207384479]
peakachu = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 7607]
peakachu_frac = [0.131107671899182, 0.235242095954013, 0.315277470705284, 0.384037143488835, 0.443289851868229, 0.476232588989609, 0.505858943179306, 0.525757240769401]
sip = [315]
sip_frac = [0.111651558699978]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('H3K27ac')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('h3k27ac_box_recovery_kr_chr6_10k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("H3K27ac")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('h3k27ac_recovery_kr_chr6_10k.png')
plt.show()
