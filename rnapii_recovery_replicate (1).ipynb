# %%
import matplotlib.pyplot as plt

# %%
tools = ['LASCA','HiCExplorer', 'FitHiC', 'FitHiChIP','Peakachu','MUSTACHE','Chromosight','SIP','cLoops','cLoops2','HiCCUPS']

# %% [markdown]
# # rnapii recovery from replicate data for chromosome 1 @ 5KB

# %%
chromosight = [1000, 1184]
chromosight_frac = [0.0134775113618555, 0.0148095909732017]
cloops = [1000, 1658]
cloops_frac = [0.0112834978843441, 0.0171603196991067]
cloops2 = [1000, 2000, 2492]
cloops2_frac = [0.00180222535652719, 0.00242908635010187, 0.00368280833725121]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 33788]
fithic_frac = [0, 0.0000783576241968344, 0.0000783576241968344, 0.0000783576241968344, 0.0000783576241968344, 0.000235072872590503, 0.00054850336937784, 0.00054850336937784, 0.00054850336937784, 0.00054850336937784, 0.00054850336937784, 0.00054850336937784, 0.00054850336937784, 0.00054850336937784, 0.00054850336937784, 0.00054850336937784, 0.00054850336937784, 0.000626860993574675, 0.000626860993574675, 0.000783576241968343, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178]
fithichip = [225]
fithichip_frac = [0.0133991537376587]
hiccups = [1000, 1943]
hiccups_frac = [0.0289139633286319, 0.0412161103275349]
hicexplorer = [1000, 1923]
hicexplorer_frac = [0.00360445071305438, 0.00736561667450243]
lasca = [1000, 2000, 3000, 3249]
lasca_frac = [0.0054850336937784, 0.0124588622472967, 0.0191192603040276, 0.0206864127879643]
mustache = [1000, 2000, 2236]
mustache_frac = [0.0102648487697853, 0.016533458705532, 0.0173953925716972]
peakachu = [905]
peakachu_frac = [0.0317348377997179]
sip = [608]
sip_frac = [0.0105782792665726]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, cloops_frac, cloops2_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('RNAPII')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('rnapii_box_recovery_replicate_chr1_5k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(cloops, cloops_frac, label = "cLoops",  marker='*', c='#ffa500')
plt.plot(cloops2, cloops2_frac, label = "cLoops2", marker='*', c='#ffff00')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("RNAPII")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('rnapii_recovery_replicate_chr1_5k.png')
plt.show()

# %% [markdown]
# # rnapii recovery from replicate data for chromosome 1 @ 10KB

# %%
chromosight = [928]
chromosight_frac = [0.0169252468265162]
cloops = [1000, 1658]
cloops_frac = [0.0112834978843441, 0.0171603196991067]
cloops2 = [1000, 2000, 2492]
cloops2_frac = [0.00180222535652719, 0.00242908635010187, 0.00368280833725121]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 25319]
fithic_frac = [0.00995141827299796, 0.0695815702867889, 0.117379721046858, 0.136185550854098, 0.138144491459019, 0.141278796426892, 0.144961604764144, 0.147860836859426, 0.148252624980411, 0.149114558846576, 0.150133207961135, 0.150681711330512, 0.151622002820874, 0.151778718069268, 0.153737658674189, 0.1559316721517, 0.159927910985739, 0.161259990597085, 0.162513712584234, 0.162905500705219, 0.164394295564958, 0.166431593794076, 0.166901739539257, 0.167998746278013, 0.168703964895784, 0.168860680144178]
fithichip = [1000, 1864]
fithichip_frac = [0.0644099670897978, 0.0932455727942329]
hiccups = [1000, 2000, 2928]
hiccups_frac = [0.0453690644099671, 0.0579846419056574, 0.0672308415608839]
hicexplorer = [1000, 1732]
hicexplorer_frac = [0.00916784203102962, 0.0138692994828397]
lasca = [1000, 1543]
lasca_frac = [0.0254662278639712, 0.0365930104999216]
mustache = [1000, 2000, 3000, 4000, 4804]
mustache_frac = [0.00305594734367654, 0.00908948440683278, 0.0110484250117536, 0.0139476571070365, 0.014652875724808]
peakachu = [1000, 2000, 2638]
peakachu_frac = [0.0130857232408713, 0.0334587055320483, 0.0564174894217207]
sip = [361]
sip_frac = [0.0100297758971948]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, cloops_frac, cloops2_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('RNAPII')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('rnapii_box_recovery_replicate_chr1_10k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(cloops, cloops_frac, label = "cLoops",  marker='*', c='#ffa500')
plt.plot(cloops2, cloops2_frac, label = "cLoops2", marker='*', c='#ffff00')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("RNAPII")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('rnapii_recovery_replicate_chr1_10k.png')
plt.show()

# %% [markdown]
# # rnapii recovery from replicate data for chromosome 6 @ 5KB

# %%
chromosight = [1000, 1184]
chromosight_frac = [0.0134775113618555, 0.0148095909732017]
cloops = [1000, 1658]
cloops_frac = [0.0112834978843441, 0.0171603196991067]
cloops2 = [1000, 2000, 2492]
cloops2_frac = [0.00180222535652719, 0.00242908635010187, 0.00368280833725121]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 33788]
fithic_frac = [0, 0.0000783576241968344, 0.0000783576241968344, 0.0000783576241968344, 0.0000783576241968344, 0.000235072872590503, 0.00054850336937784, 0.00054850336937784, 0.00054850336937784, 0.00054850336937784, 0.00054850336937784, 0.00054850336937784, 0.00054850336937784, 0.00054850336937784, 0.00054850336937784, 0.00054850336937784, 0.00054850336937784, 0.000626860993574675, 0.000626860993574675, 0.000783576241968343, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178, 0.000861933866165178]
fithichip = [225]
fithichip_frac = [0.0133991537376587]
hiccups = [1000, 1943]
hiccups_frac = [0.0289139633286319, 0.0412161103275349]
hicexplorer = [1000, 1923]
hicexplorer_frac = [0.00360445071305438, 0.00736561667450243]
lasca = [1000, 2000, 3000, 3249]
lasca_frac = [0.0054850336937784, 0.0124588622472967, 0.0191192603040276, 0.0206864127879643]
mustache = [1000, 2000, 2236]
mustache_frac = [0.0102648487697853, 0.016533458705532, 0.0173953925716972]
peakachu = [905]
peakachu_frac = [0.0317348377997179]
sip = [608]
sip_frac = [0.0105782792665726]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, cloops_frac, cloops2_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('RNAPII')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('rnapii_box_recovery_replicate_chr6_5k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(cloops, cloops_frac, label = "cLoops",  marker='*', c='#ffa500')
plt.plot(cloops2, cloops2_frac, label = "cLoops2", marker='*', c='#ffff00')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("RNAPII")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('rnapii_recovery_replicate_chr6_5k.png')
plt.show()

# %% [markdown]
# # rnapii recovery from replicate data for chromosome 6 @ 10KB

# %%
chromosight = [928]
chromosight_frac = [0.0169252468265162]
cloops = [1000, 1658]
cloops_frac = [0.0112834978843441, 0.0171603196991067]
cloops2 = [1000, 2000, 2492]
cloops2_frac = [0.00180222535652719, 0.00242908635010187, 0.00368280833725121]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 25319]
fithic_frac = [0.00995141827299796, 0.0695815702867889, 0.117379721046858, 0.136185550854098, 0.138144491459019, 0.141278796426892, 0.144961604764144, 0.147860836859426, 0.148252624980411, 0.149114558846576, 0.150133207961135, 0.150681711330512, 0.151622002820874, 0.151778718069268, 0.153737658674189, 0.1559316721517, 0.159927910985739, 0.161259990597085, 0.162513712584234, 0.162905500705219, 0.164394295564958, 0.166431593794076, 0.166901739539257, 0.167998746278013, 0.168703964895784, 0.168860680144178]
fithichip = [1000, 1864]
fithichip_frac = [0.0644099670897978, 0.0932455727942329]
hiccups = [1000, 2000, 2928]
hiccups_frac = [0.0453690644099671, 0.0579846419056574, 0.0672308415608839]
hicexplorer = [1000, 1732]
hicexplorer_frac = [0.00916784203102962, 0.0138692994828397]
lasca = [1000, 1543]
lasca_frac = [0.0254662278639712, 0.0365930104999216]
mustache = [1000, 2000, 3000, 4000, 4804]
mustache_frac = [0.00305594734367654, 0.00908948440683278, 0.0110484250117536, 0.0139476571070365, 0.014652875724808]
peakachu = [1000, 2000, 2638]
peakachu_frac = [0.0130857232408713, 0.0334587055320483, 0.0564174894217207]
sip = [361]
sip_frac = [0.0100297758971948]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, cloops_frac, cloops2_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('RNAPII')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('rnapii_box_recovery_replicate_chr6_10k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(cloops, cloops_frac, label = "cLoops",  marker='*', c='#ffa500')
plt.plot(cloops2, cloops2_frac, label = "cLoops2", marker='*', c='#ffff00')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("RNAPII")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('rnapii_recovery_replicate_chr6_10k.png')
plt.show()
