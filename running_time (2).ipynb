# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# make data
x_labels = np.array(['LASCA','HiCExplorer', 'FitHiC', 'FitHiChIP','Peakachu','Mustache','Chromosight','SIP','cLoops','cLoops2','HiCCUPS'])
y_labels = np.array([1646.77,	1662.00,	2126.33,	36864.00,	458.17,	300.42,	2457.00,	3454.33,	34127.50,	70920.00,	237.25])

# %%
data = pd.DataFrame({
    'LASCA':[1646.77],
    'HiCExplorer':[1662.00], 
    'FitHiC':[2126.33], 
    'FitHiChIP':[36864.00],
    'Peakachu':[458.17],
    'Mustache':[300.42],
    'Chromosight':[2457.00],
    'SIP':[3454.33],
    'cLoops':[34127.50],
    'cLoops2':[70920.00],
    'HiCCUPS':[237.25]})

# %%
plt.figure(figsize=(10, 4))
sns.barplot(data=data,
            order = ['LASCA','HiCExplorer', 'FitHiC', 'FitHiChIP','Peakachu','Mustache','Chromosight','SIP','cLoops','cLoops2','HiCCUPS'],
            palette = "muted",
            orient="h"
           )
plt.title("Average Running Time")
plt.xlabel("seconds")
plt.ylabel("Tools")
plt.savefig('running_time.png', bbox_inches='tight')
plt.show()

# %%
data = pd.DataFrame({
    'LASCA':[1646.77],
    'HiCExplorer':[1662.00], 
    'FitHiC':[2126.33], 
    'FitHiChIP':[3600.00],
    'Peakachu':[458.17],
    'Mustache':[300.42],
    'Chromosight':[2457.00],
    'SIP':[3454.33],
    'cLoops':[3600.00],
    'cLoops2':[3600.00],
    'HiCCUPS':[237.25]})
plt.figure(figsize=(7, 3))
sns.barplot(data=data,
            order = ['LASCA','HiCExplorer', 'FitHiC', 'FitHiChIP','Peakachu','Mustache','Chromosight','SIP','cLoops','cLoops2','HiCCUPS'],
            palette = "muted",
            orient="h"
           )
plt.title("Average Running Time (seconds)")
plt.savefig('running_time_short.png', bbox_inches='tight')
plt.show()

# %%
data = pd.DataFrame({
    'MNIST CNN':[98.75],
    'MNIST VGG16':[10.53], 
    'MNIST ResNet50':[31.47], 
    'CIFAR10 CNN':[70.64],
    'CIFAR10 VGG16':[61.41],
    'CIFAR10 ResNet50':[38.39],
    'ImageNet CNN':[46.83],
    'ImageNet VGG16':[58.22],
    'ImageNet ResNet50':[91.72]})
plt.figure(figsize=(7, 3))
sns.barplot(data=data,
            order = ['MNIST CNN','MNIST VGG16', 'MNIST ResNet50', 'CIFAR10 CNN','CIFAR10 VGG16','CIFAR10 ResNet50','ImageNet CNN','ImageNet VGG16','ImageNet ResNet50'],
            palette = "muted",
            orient="h"
           )
plt.title("Evaluation Accuracy")
plt.savefig('eva_acc.png', bbox_inches='tight')
plt.show()
