# %%
import matplotlib.pyplot as plt

# %%
tools = ['LASCA','HiCExplorer', 'FitHiC', 'FitHiChIP','Peakachu','MUSTACHE','Chromosight','SIP','HiCCUPS']

# %% [markdown]
# # CTCF recovery from KR data for chromosome 1 @ 5KB

# %%
chromosight = [1000, 1414]
chromosight_frac = [0.0585241730279898, 0.0622349448685327]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 33220]
fithic_frac = [0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876]
fithichip = [769]
fithichip_frac = [0]
hiccups = [1000, 2000, 3000, 3300]
hiccups_frac = [0.075275657336726, 0.124045801526718, 0.152565733672604, 0.15998727735369]
hicexplorer = [1000, 1757]
hicexplorer_frac = [0.0395462256149279, 0.0652035623409669]
lasca = [1000, 2000, 3000, 3146]
lasca_frac = [0.00710347752332485, 0.0177056827820187, 0.030746395250212, 0.0310644614079729]
mustache = [1000, 2000, 2808]
mustache_frac = [0.0460135708227311, 0.0937234944868533, 0.118850720949958]
peakachu = [1000, 2000, 3000, 3867]
peakachu_frac = [0.0212044105173876, 0.0441051738761662, 0.0710347752332485, 0.0997667514843087]
sip = [747]
sip_frac = [0.0843935538592027]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('CTCF')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('ctcf_box_recovery_kr_chr1_5k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("CTCF")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('ctcf_recovery_kr_chr1_5k.png')
plt.show()

# %% [markdown]
# # CTCF recovery from RAW data for chromosome 1 @ 10KB

# %%
chromosight = [958]
chromosight_frac = [0.0584181509754029]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 31575]
fithic_frac = [0.0189779474130619, 0.0390161153519932, 0.0430449533502969, 0.0463316369804919, 0.0470737913486005, 0.0499363867684478, 0.0586301950805768, 0.0596904156064461, 0.0646734520780322, 0.0652035623409669, 0.0653095843935539, 0.0658396946564885, 0.0661577608142494, 0.066793893129771, 0.066793893129771, 0.0668999151823579, 0.0668999151823579, 0.0670059372349449, 0.0671119592875318, 0.0671119592875318, 0.0675360474978796, 0.0677480916030534, 0.0691263782866836, 0.0692324003392706, 0.0696564885496183, 0.0698685326547922, 0.0698685326547922, 0.0705046649703138, 0.0706106870229008, 0.0707167090754877, 0.0707167090754877, 0.0708227311280746]
fithichip = [1000, 2000, 3000, 3678]
fithichip_frac = [0, 0, 0, 0]
hiccups = [1000, 2000, 3000, 3888]
hiccups_frac = [0.133799830364716, 0.199533502968617, 0.249045801526718, 0.274491094147583]
hicexplorer = [1000, 1471]
hicexplorer_frac = [0.0796225614927905, 0.105491942324003]
lasca = [1000, 1503]
lasca_frac = [0.0333969465648855, 0.051420695504665]
mustache = [1000, 2000, 3000, 4000, 5000, 5843]
mustache_frac = [0.0214164546225615, 0.0473918575063613, 0.0797285835453774, 0.0994486853265479, 0.11736641221374, 0.124681933842239]
peakachu = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 7607]
peakachu_frac = [0.0162213740458015, 0.0322307039864292, 0.0522688719253605, 0.0773960983884648, 0.107188295165394, 0.140055131467345, 0.188401187446989, 0.241200169635284]
sip = [315]
sip_frac = [0.0579940627650551]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('CTCF')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('ctcf_box_recovery_kr_chr1_10k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("CTCF")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('ctcf_recovery_kr_chr1_10k.png')
plt.show()

# %% [markdown]
# # CTCF recovery from KR data for chromosome 6 @ 5KB

# %%
chromosight = [1000, 1414]
chromosight_frac = [0.0585241730279898, 0.0622349448685327]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 33220]
fithic_frac = [0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876]
fithichip = [769]
fithichip_frac = [0]
hiccups = [1000, 2000, 3000, 3300]
hiccups_frac = [0.075275657336726, 0.124045801526718, 0.152565733672604, 0.15998727735369]
hicexplorer = [1000, 1757]
hicexplorer_frac = [0.0395462256149279, 0.0652035623409669]
lasca = [1000, 2000, 3000, 3146]
lasca_frac = [0.00710347752332485, 0.0177056827820187, 0.030746395250212, 0.0310644614079729]
mustache = [1000, 2000, 2808]
mustache_frac = [0.0460135708227311, 0.0937234944868533, 0.118850720949958]
peakachu = [1000, 2000, 3000, 3867]
peakachu_frac = [0.0212044105173876, 0.0441051738761662, 0.0710347752332485, 0.0997667514843087]
sip = [747]
sip_frac = [0.0843935538592027]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('CTCF')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('ctcf_box_recovery_kr_chr6_5k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("CTCF")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('ctcf_recovery_kr_chr6_5k.png')
plt.show()

# %% [markdown]
# # CTCF recovery from KR data for chromosome 6 @ 10KB

# %%
chromosight = [958]
chromosight_frac = [0.0584181509754029]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 31575]
fithic_frac = [0.0189779474130619, 0.0390161153519932, 0.0430449533502969, 0.0463316369804919, 0.0470737913486005, 0.0499363867684478, 0.0586301950805768, 0.0596904156064461, 0.0646734520780322, 0.0652035623409669, 0.0653095843935539, 0.0658396946564885, 0.0661577608142494, 0.066793893129771, 0.066793893129771, 0.0668999151823579, 0.0668999151823579, 0.0670059372349449, 0.0671119592875318, 0.0671119592875318, 0.0675360474978796, 0.0677480916030534, 0.0691263782866836, 0.0692324003392706, 0.0696564885496183, 0.0698685326547922, 0.0698685326547922, 0.0705046649703138, 0.0706106870229008, 0.0707167090754877, 0.0707167090754877, 0.0708227311280746]
fithichip = [1000, 2000, 3000, 3678]
fithichip_frac = [0, 0, 0, 0]
hiccups = [1000, 2000, 3000, 3888]
hiccups_frac = [0.133799830364716, 0.199533502968617, 0.249045801526718, 0.274491094147583]
hicexplorer = [1000, 1471]
hicexplorer_frac = [0.0796225614927905, 0.105491942324003]
lasca = [1000, 1503]
lasca_frac = [0.0333969465648855, 0.051420695504665]
mustache = [1000, 2000, 3000, 4000, 5000, 5843]
mustache_frac = [0.0214164546225615, 0.0473918575063613, 0.0797285835453774, 0.0994486853265479, 0.11736641221374, 0.124681933842239]
peakachu = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 7607]
peakachu_frac = [0.0162213740458015, 0.0322307039864292, 0.0522688719253605, 0.0773960983884648, 0.107188295165394, 0.140055131467345, 0.188401187446989, 0.241200169635284]
sip = [315]
sip_frac = [0.0579940627650551]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('CTCF')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('ctcf_box_recovery_kr_chr6_10k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("CTCF")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('ctcf_recovery_kr_chr6_10k.png')
plt.show()
