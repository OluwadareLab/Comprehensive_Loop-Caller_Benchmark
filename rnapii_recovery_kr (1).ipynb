# %%
import matplotlib.pyplot as plt

# %%
tools = ['LASCA','HiCExplorer', 'FitHiC', 'FitHiChIP','Peakachu','MUSTACHE','Chromosight','SIP','HiCCUPS']

# %% [markdown]
# # rnapii recovery from RAW data for chromosome 1 @ 5KB

# %%
chromosight = [1000, 1414]
chromosight_frac = [0.0150446638457922, 0.0173170349475004]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 33220]
fithic_frac = [0, 0.000705218617771509, 0.000705218617771509, 0.000705218617771509, 0.000705218617771509, 0.000705218617771509, 0.000861933866165178, 0.00109700673875568, 0.00109700673875568, 0.00109700673875568, 0.00109700673875568, 0.00109700673875568, 0.00109700673875568, 0.00109700673875568, 0.00109700673875568, 0.00109700673875568, 0.00109700673875568, 0.00117536436295252, 0.00117536436295252, 0.00133207961134618, 0.00141043723554302, 0.00141043723554302, 0.00148879485973985, 0.00148879485973985, 0.00148879485973985, 0.00148879485973985, 0.00148879485973985, 0.00156715248393669, 0.00156715248393669, 0.00156715248393669, 0.00156715248393669, 0.00156715248393669, 0.00156715248393669, 0.00156715248393669]
fithichip = [769]
fithichip_frac = [0]
hiccups = [1000, 2000, 3000, 3300]
hiccups_frac = [0.0333019902836546, 0.0485817270020373, 0.0590032910202163, 0.0611189468735308]
hicexplorer = [1000, 1757]
hicexplorer_frac = [0.00720890142610876, 0.0115185707569346]
lasca = [1000, 2000, 3000, 3146]
lasca_frac = [0.00634696755994358, 0.0102648487697853, 0.016533458705532, 0.0177088230684846]
mustache = [1000, 2000, 2808]
mustache_frac = [0.00901112678263595, 0.0167685315781226, 0.0202162670427833]
peakachu = [1000, 2000, 3000, 3867]
peakachu_frac = [0.01089170976336, 0.0259363736091522, 0.0456041372825576, 0.0732643786240401]
sip = [747]
sip_frac = [0.0153580943425795]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('RNAPII')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('rnapii_box_recovery_kr_chr1_5k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("RNAPII")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('rnapii_recovery_kr_chr1_5k.png')
plt.show()

# %% [markdown]
# # rnapii recovery from RAW data for chromosome 1 @ 10KB

# %%
chromosight = [958]
chromosight_frac = [0.0170819620749099]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 31575]
fithic_frac = [0.00861933866165178, 0.0697382855351826, 0.112208117849867, 0.14159222692368, 0.160241341482526, 0.180144178028522, 0.220733427362482, 0.234132581100141, 0.262419683435198, 0.271587525466228, 0.273703181319542, 0.276132267669644, 0.280598652248864, 0.28365459959254, 0.285065036828083, 0.285456824949068, 0.286240401191036, 0.287494123178185, 0.288512772292744, 0.288747845165335, 0.290550070521862, 0.292665726375176, 0.297915687196364, 0.298777621062529, 0.300031343049679, 0.301049992164238, 0.301911926030403, 0.304889515749882, 0.305516376743457, 0.306378310609622, 0.307396959724181, 0.308023820717756]
fithichip = [1000, 2000, 3000, 3678]
fithichip_frac = [0, 0, 0, 0]
hiccups = [1000, 2000, 3000, 3888]
hiccups_frac = [0.0459175677793449, 0.0640181789688137, 0.0754583921015515, 0.0822755054066761]
hicexplorer = [1000, 1471]
hicexplorer_frac = [0.012772292744084, 0.0168468892023194]
lasca = [1000, 1503]
lasca_frac = [0.0276602413414825, 0.0351825732643786]
mustache = [1000, 2000, 3000, 4000, 5000, 5843]
mustache_frac = [0.00188058298072402, 0.00587682181476258, 0.0104999216423758, 0.0120670741263125, 0.0129290079924777, 0.0139476571070365]
peakachu = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 7607]
peakachu_frac = [0.00321266259207021, 0.00877605391004545, 0.0147312333490049, 0.0213132737815389, 0.0311079768061432, 0.0427832628114716, 0.0590032910202163, 0.086115028992321]
sip = [315]
sip_frac = [0.0102648487697853]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('RNAPII')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('rnapii_box_recovery_kr_chr1_10k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("RNAPII")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('rnapii_recovery_kr_chr1_10k.png')
plt.show()

# %% [markdown]
# # rnapii recovery from RAW data for chromosome 6 @ 5KB

# %%
chromosight = [1000, 1414]
chromosight_frac = [0.0150446638457922, 0.0173170349475004]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 33220]
fithic_frac = [0, 0.000705218617771509, 0.000705218617771509, 0.000705218617771509, 0.000705218617771509, 0.000705218617771509, 0.000861933866165178, 0.00109700673875568, 0.00109700673875568, 0.00109700673875568, 0.00109700673875568, 0.00109700673875568, 0.00109700673875568, 0.00109700673875568, 0.00109700673875568, 0.00109700673875568, 0.00109700673875568, 0.00117536436295252, 0.00117536436295252, 0.00133207961134618, 0.00141043723554302, 0.00141043723554302, 0.00148879485973985, 0.00148879485973985, 0.00148879485973985, 0.00148879485973985, 0.00148879485973985, 0.00156715248393669, 0.00156715248393669, 0.00156715248393669, 0.00156715248393669, 0.00156715248393669, 0.00156715248393669, 0.00156715248393669]
fithichip = [769]
fithichip_frac = [0]
hiccups = [1000, 2000, 3000, 3300]
hiccups_frac = [0.0333019902836546, 0.0485817270020373, 0.0590032910202163, 0.0611189468735308]
hicexplorer = [1000, 1757]
hicexplorer_frac = [0.00720890142610876, 0.0115185707569346]
lasca = [1000, 2000, 3000, 3146]
lasca_frac = [0.00634696755994358, 0.0102648487697853, 0.016533458705532, 0.0177088230684846]
mustache = [1000, 2000, 2808]
mustache_frac = [0.00901112678263595, 0.0167685315781226, 0.0202162670427833]
peakachu = [1000, 2000, 3000, 3867]
peakachu_frac = [0.01089170976336, 0.0259363736091522, 0.0456041372825576, 0.0732643786240401]
sip = [747]
sip_frac = [0.0153580943425795]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('RNAPII')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('rnapii_box_recovery_kr_chr6_5k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("RNAPII")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('rnapii_recovery_kr_chr6_5k.png')
plt.show()

# %% [markdown]
# # rnapii recovery from RAW data for chromosome 6 @ 10KB

# %%
chromosight = [958]
chromosight_frac = [0.0170819620749099]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 31575]
fithic_frac = [0.00861933866165178, 0.0697382855351826, 0.112208117849867, 0.14159222692368, 0.160241341482526, 0.180144178028522, 0.220733427362482, 0.234132581100141, 0.262419683435198, 0.271587525466228, 0.273703181319542, 0.276132267669644, 0.280598652248864, 0.28365459959254, 0.285065036828083, 0.285456824949068, 0.286240401191036, 0.287494123178185, 0.288512772292744, 0.288747845165335, 0.290550070521862, 0.292665726375176, 0.297915687196364, 0.298777621062529, 0.300031343049679, 0.301049992164238, 0.301911926030403, 0.304889515749882, 0.305516376743457, 0.306378310609622, 0.307396959724181, 0.308023820717756]
fithichip = [1000, 2000, 3000, 3678]
fithichip_frac = [0, 0, 0, 0]
hiccups = [1000, 2000, 3000, 3888]
hiccups_frac = [0.0459175677793449, 0.0640181789688137, 0.0754583921015515, 0.0822755054066761]
hicexplorer = [1000, 1471]
hicexplorer_frac = [0.012772292744084, 0.0168468892023194]
lasca = [1000, 1503]
lasca_frac = [0.0276602413414825, 0.0351825732643786]
mustache = [1000, 2000, 3000, 4000, 5000, 5843]
mustache_frac = [0.00188058298072402, 0.00587682181476258, 0.0104999216423758, 0.0120670741263125, 0.0129290079924777, 0.0139476571070365]
peakachu = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 7607]
peakachu_frac = [0.00321266259207021, 0.00877605391004545, 0.0147312333490049, 0.0213132737815389, 0.0311079768061432, 0.0427832628114716, 0.0590032910202163, 0.086115028992321]
sip = [315]
sip_frac = [0.0102648487697853]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('RNAPII')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('rnapii_box_recovery_kr_chr6_10k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("RNAPII")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('rnapii_recovery_kr_chr6_10k.png')
plt.show()
