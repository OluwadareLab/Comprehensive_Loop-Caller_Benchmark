# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # CTCF recovery from RAW data for chromosome 1 @ 5KB

# %%
tools = ['LASCA','HiCExplorer', 'FitHiC', 'FitHiChIP','Peakachu','MUSTACHE','Chromosight','SIP','cLoops','cLoops2','HiCCUPS']

# %%
chromosight = [1000, 1426]
chromosight_frac = [0.0585241730279898, 0.0619168787107718]
cloops = [154]
cloops_frac = [0.0364715860899067]
cloops2 = [76]
cloops2_frac = [0.0365776081424936]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 33220]
fithic_frac = [0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876]
fithichip = [770]
fithichip_frac = [0.0476039016115352]
hiccups = [1000, 2000, 3000, 3300]
hiccups_frac = [0.075381679389313, 0.123727735368957, 0.152671755725191, 0.15998727735369]
hicexplorer = [1000, 2000, 2334]
hicexplorer_frac = [0.0293681085665818, 0.0627650551314674, 0.0712468193384224]
lasca = [1000, 2000, 2801]
lasca_frac = [0.00826972010178117, 0.0215224766751484, 0.0319126378286684]
mustache = [1000, 2000, 3000, 3748]
mustache_frac = [0.0370016963528414, 0.0679601357082273, 0.102735368956743, 0.123197625106022]
peakachu = [1000, 1953]
peakachu_frac = [0.0384860050890585, 0.0789864291772689]
sip = [1000, 1442]
sip_frac = [0.0443172179813401, 0.0641433418150975]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, cloops_frac, cloops2_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('CTCF')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('ctcf_box_recovery_raw_chr1_5k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(cloops, cloops_frac, label = "cLoops",  marker='*', c='#ffa500')
plt.plot(cloops2, cloops2_frac, label = "cLoops2", marker='*', c='#ffff00')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("CTCF")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('ctcf_recovery_raw_chr1_5k.png')
plt.show()

# %% [markdown]
# # CTCF recovery from RAW data for chromosome 1 @ 10KB

# %%
chromosight = [951]
chromosight_frac = [0.0559796437659033]
cloops = [154]
cloops_frac = [0.0364715860899067]
cloops2 = [76]
cloops2_frac = [0.0365776081424936]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 31575]
fithic_frac = [0.0189779474130619, 0.0390161153519932, 0.0430449533502969, 0.0463316369804919, 0.0470737913486005, 0.0499363867684478, 0.0586301950805768, 0.0596904156064461, 0.0646734520780322, 0.0652035623409669, 0.0653095843935539, 0.0658396946564885, 0.0661577608142494, 0.066793893129771, 0.066793893129771, 0.0668999151823579, 0.0668999151823579, 0.0670059372349449, 0.0671119592875318, 0.0671119592875318, 0.0675360474978796, 0.0677480916030534, 0.0691263782866836, 0.0692324003392706, 0.0696564885496183, 0.0698685326547922, 0.0698685326547922, 0.0705046649703138, 0.0706106870229008, 0.0707167090754877, 0.0707167090754877, 0.0708227311280746]
fithichip = [1000, 2000, 3000, 3693]
fithichip_frac = [0.0904368108566582, 0.128286683630195, 0.151187446988974, 0.164864291772689]
hiccups = [1000, 2000, 3000, 3888]
hiccups_frac = [0.133799830364716, 0.199533502968617, 0.249045801526718, 0.274491094147583]
hicexplorer = [1000, 1970]
hicexplorer_frac = [0.0459075487701442, 0.0949957591178965]
lasca = [1000, 1332]
lasca_frac = [0.0383799830364716, 0.051314673452078]
mustache = [1000, 2000, 2017]
mustache_frac = [0.078774385072095, 0.116730279898219, 0.116836301950806]
peakachu = [1000, 2000, 2312]
peakachu_frac = [0.0501484308736217, 0.110687022900763, 0.147794741306192]
sip = [249]
sip_frac = [0.0417726887192536]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, cloops_frac, cloops2_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('CTCF')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('ctcf_box_recovery_raw_chr1_10k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(cloops, cloops_frac, label = "cLoops",  marker='*', c='#ffa500')
plt.plot(cloops2, cloops2_frac, label = "cLoops2", marker='*', c='#ffff00')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("CTCF")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('ctcf_recovery_raw_chr1_10k.png')
plt.show()

# %% [markdown]
# # CTCF recovery from RAW data for chromosome 6 @ 5KB

# %%
chromosight = [1000, 1426]
chromosight_frac = [0.0585241730279898, 0.0619168787107718]
cloops = [154]
cloops_frac = [0.0364715860899067]
cloops2 = [76]
cloops2_frac = [0.0365776081424936]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 33220]
fithic_frac = [0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876, 0.000212044105173876]
fithichip = [770]
fithichip_frac = [0.0476039016115352]
hiccups = [1000, 2000, 3000, 3300]
hiccups_frac = [0.075381679389313, 0.123727735368957, 0.152671755725191, 0.15998727735369]
hicexplorer = [1000, 2000, 2334]
hicexplorer_frac = [0.0293681085665818, 0.0627650551314674, 0.0712468193384224]
lasca = [1000, 2000, 2801]
lasca_frac = [0.00826972010178117, 0.0215224766751484, 0.0319126378286684]
mustache = [1000, 2000, 3000, 3748]
mustache_frac = [0.0370016963528414, 0.0679601357082273, 0.102735368956743, 0.123197625106022]
peakachu = [1000, 1953]
peakachu_frac = [0.0384860050890585, 0.0789864291772689]
sip = [1000, 1442]
sip_frac = [0.0443172179813401, 0.0641433418150975]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, cloops_frac, cloops2_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('CTCF')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('ctcf_box_recovery_raw_chr6_5k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(cloops, cloops_frac, label = "cLoops",  marker='*', c='#ffa500')
plt.plot(cloops2, cloops2_frac, label = "cLoops2", marker='*', c='#ffff00')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("CTCF")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('ctcf_recovery_raw_chr6_5k.png')
plt.show()

# %% [markdown]
# # CTCF recovery from RAW data for chromosome 6 @ 10KB

# %%
chromosight = [951]
chromosight_frac = [0.0559796437659033]
cloops = [154]
cloops_frac = [0.0364715860899067]
cloops2 = [76]
cloops2_frac = [0.0365776081424936]
fithic = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 31575]
fithic_frac = [0.0189779474130619, 0.0390161153519932, 0.0430449533502969, 0.0463316369804919, 0.0470737913486005, 0.0499363867684478, 0.0586301950805768, 0.0596904156064461, 0.0646734520780322, 0.0652035623409669, 0.0653095843935539, 0.0658396946564885, 0.0661577608142494, 0.066793893129771, 0.066793893129771, 0.0668999151823579, 0.0668999151823579, 0.0670059372349449, 0.0671119592875318, 0.0671119592875318, 0.0675360474978796, 0.0677480916030534, 0.0691263782866836, 0.0692324003392706, 0.0696564885496183, 0.0698685326547922, 0.0698685326547922, 0.0705046649703138, 0.0706106870229008, 0.0707167090754877, 0.0707167090754877, 0.0708227311280746]
fithichip = [1000, 2000, 3000, 3693]
fithichip_frac = [0.0904368108566582, 0.128286683630195, 0.151187446988974, 0.164864291772689]
hiccups = [1000, 2000, 3000, 3888]
hiccups_frac = [0.133799830364716, 0.199533502968617, 0.249045801526718, 0.274491094147583]
hicexplorer = [1000, 1970]
hicexplorer_frac = [0.0459075487701442, 0.0949957591178965]
lasca = [1000, 1332]
lasca_frac = [0.0383799830364716, 0.051314673452078]
mustache = [1000, 2000, 2017]
mustache_frac = [0.078774385072095, 0.116730279898219, 0.116836301950806]
peakachu = [1000, 2000, 2312]
peakachu_frac = [0.0501484308736217, 0.110687022900763, 0.147794741306192]
sip = [249]
sip_frac = [0.0417726887192536]

# %%
all_data = [lasca_frac, hicexplorer_frac, fithic_frac, fithichip_frac, peakachu_frac, mustache_frac, chromosight_frac, sip_frac, cloops_frac, cloops2_frac, hiccups_frac]
fig, axs = plt.subplots(figsize=(10, 5))
axs.boxplot(all_data)
axs.set_title('CTCF')
axs.yaxis.grid(True)
axs.set_xticks([y + 1 for y in range(len(all_data))], labels=tools)
axs.set_xlabel(None)
axs.set_ylabel('Fraction')
plt.savefig('ctcf_box_recovery_raw_chr6_10k.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.plot(chromosight, chromosight_frac, label = "Chromosight",  marker='p', c='#ff0000')
plt.plot(cloops, cloops_frac, label = "cLoops",  marker='*', c='#ffa500')
plt.plot(cloops2, cloops2_frac, label = "cLoops2", marker='*', c='#ffff00')
plt.plot(fithic, fithic_frac, label = "FitHiC", marker='x', c='#795548')
plt.plot(fithichip, fithichip_frac, label = "FitHiChIP", marker='x', c='#0000ff')
plt.plot(hiccups, hiccups_frac, label = "HICCUPS", marker='*',  c='#4b0082')
plt.plot(hicexplorer, hicexplorer_frac, label = "HiCExplorer", marker='x', c='#ff5300')
plt.plot(lasca, lasca_frac, label = "LASCA", marker='*', c='#ffd200')
plt.plot(mustache, mustache_frac, label = "Mustache",  marker='p', c='#80c000')
plt.plot(peakachu, peakachu_frac, label = "Peakachu", marker='+', c='#004080')
plt.plot(sip, sip_frac, label = "SIP", marker='p', c='#607d8b')
plt.xlim([0, 10000])
plt.title("CTCF")
plt.xlabel("Loop")
plt.ylabel("Fraction")
plt.legend()
plt.savefig('ctcf_recovery_raw_chr6_10k.png')
plt.show()
